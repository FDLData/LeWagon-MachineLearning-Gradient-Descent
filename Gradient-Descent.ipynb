# %% [markdown]
# # Gradient Descent

# %% [markdown]
# In this exercise, you will create the necessary functions to go through the steps of a single Gradient Descent Epoch. You will then combine the functions and create a loop through the entire Gradient Descent procedure.

# %% [markdown]
# ## 1. Data Exploration

# %% [markdown]
# We will import for you the following dataset of ingredients with their mineral content

# %%
import pandas as pd

data = pd.read_csv("https://wagon-public-datasets.s3.amazonaws.com/05-Machine-Learning/04-Under-the-Hood/gradient_descent_ingredients_zinc_phosphorous.csv")
data.head()
# Out:
#                                              aliment      zinc  phosphorus
# 0  Durum wheat pre-cooked. whole grain. cooked. u...  0.120907    0.193784
# 1             Asian noodles. plain. cooked. unsalted  0.047859    0.060329
# 2                      Rice. brown. cooked. unsalted  0.156171    0.201097
# 3                             Rice. cooked. unsalted  0.065491    0.045704
# 4                  Rice. parboiled. cooked. unsalted  0.025189    0.045704

# %% [markdown]
# 👇 We can visualize a somewhat Linear relationship between the `Phosphorus` and `Zinc`.
#
# Let's use Gradient Descent to find the line of best fit between them!

# %%
import seaborn as sns

sns.scatterplot(data=data, x='zinc', y='phosphorus');

# %% [markdown]
# ❓ Create the two `np.Array`
# - `data_X` for zinc
# - `data_Y` for phosphorus

# %%
import numpy as np
data_X = np.array(data['zinc'])
data_Y = np.array(data['phosphorus'])

# %%
assert (data_X.shape == (53,))
assert (data_Y.shape == (53,))

# %% [markdown]
# ## 2. Code one Epoch

# %% [markdown]
# In this section of the exercise, you will define the key functions used to update the parameters during one epoch $\color {red}{(k)}$ of gradient descent. Recall the formula below
#
# $$
# \beta_0^{\color {red}{(k+1)}} = \beta_0^{\color {red}{(k)}} - \eta \frac{\partial L}{\partial \beta_0}(\beta^{\color{red}{(k)}})
# $$
#
#
# $$
# \beta_1^{\color {red}{(k+1)}} = \beta_1^{\color {red}{(k)}} - \eta \frac{\partial L}{\partial \beta_1}(\beta^{\color {red}{(k)}})
# $$

# %% [markdown]
# ### 2.1 Hypothesis Function

# %% [markdown]
# $$
# \hat{y} =  a x + b
# $$
#
# ❓ Define the hypothesis function of a Linear Regression. Let `a` be the slope and `b` the intercept.

# %%
def h(X,a,b):
    return a*X + b

# %% [markdown]
# ### 2.2 Loss Function

# %% [markdown]
# $$
# Sum\ Squares\ Loss = \sum_{i=0}^n (y^{(i)} - \hat{y}^{(i)} )^2
# $$
#
# ❓ Define the SSR Loss Function for the Hypothesis Function using the equation above. Reuse the function `h` coded above when writing your new function.

# %%
import numpy as np

def loss(X,Y,a,b):
    return  np.sum((Y - h(X,a,b))**2)

# %% [markdown]
# ❓ What would be the total Loss computed on all our ingredients dataset if:
# - a = 1
# - b = 1

# %%
loss(data_X,data_Y,1,1)
# Out:
# 63.868506986115456

# %% [markdown]
# ⚠️ You should be getting 63.86. If not, something is wrong with your function. Fix it before moving on!

# %% [markdown]
# ### 2.3 Gradient

# %% [markdown]
# $$
# \frac{d\ SSR}{d\ slope}= \sum_{i=0}^n -2  x_i (y^{(i)} - \hat{y}^{(i)} )
# $$
#
# $$
# \frac{d\ SSR}{d\ intercept}= \sum_{i=0}^n -2(y^{(i)} - \hat{y}^{(i)} )
# $$
#
# ❓ Define a function to compute the partial derivatives of the Loss Function relative to parameter `a` and `b` at a given point.

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
# Again, you must re-use the Hypothesis Function in your new function to compute the predictions at given points.
# </details>

# %%
def gradient(X,Y,a,b):
    d_a = np.sum(-2*X*(Y-h(X,a,b)))
    d_b =np.sum(-2*(Y-h(X,a,b)))
    return d_a, d_b

# %% [markdown]
# ❓ Using your function, what would be the partial derivatives of each parameter if:
# - a = 1
# - b = 1

# %%
gradient(data_X, data_Y,1,1)
# Out:
# (48.459065809109006, 115.17923733301406)

# %% [markdown]
# ⚠️ You should be getting 48.45 and  115.17. If not, fix your function!

# %% [markdown]
# ### 2.4 Step Sizes

# %% [markdown]
# $$
# step\ size = gradient \cdot learning\ rate
# $$

# %% [markdown]
# ❓ Define a function that calculates the step sizes alongside each parameter (`a`,`b`), according to their derivatives (`d_a`, `d_b`) and a `learning_rate` equal to `0.01` by default

# %%
def steps(d_a,d_b, learning_rate = 0.01):
    step_a = d_a * learning_rate
    step_b = d_b * learning_rate
    return (step_a, step_b)

# %% [markdown]
# ❓ What would be the steps (`step_a`, `step_b`) to take for the derivatives computed above for (`a`,`b`) = (1,1)?

# %%
steps(gradient(data_X, data_Y,1,1)[0], gradient(data_X, data_Y,1,1)[1])
# Out:
# (0.4845906580910901, 1.1517923733301405)

# %% [markdown]
# ⚠️ The steps should be 0.48 for `a` and 1.15 for `b`

# %% [markdown]
# ### 2.5 Update parameters (a, b)

# %% [markdown]
# $$
# updated\ parameter = old\ parameter\ value - step\ size
# $$

# %% [markdown]
# ❓ Define a function that computes the updated parameter values from the old parameter values and the step sizes.

# %%
def update_params(a, b, step_a, step_b):
    a_new = a - step_a
    b_new = b - step_b
    return a_new , b_new

# %% [markdown]
# ### 2.6 One full epoch

# %% [markdown]
# ❓ Using the functions you just created, compute the updated parameters at the end of the first Epoch, had you started with parameters:
# - a = 1
# - b = 1

# %%
update_params(1, 1, steps(gradient(data_X, data_Y,1,1)[0], gradient(data_X, data_Y,1,1)[1])[0], steps(gradient(data_X, data_Y,1,1)[0], gradient(data_X, data_Y,1,1)[1])[1])
# Out:
# (0.5154093419089099, -0.1517923733301405)

# %% [markdown]
# ⚠️ You should be getting the following values:
#    - updated_a = 0.51
#    - updated_b = -0.15

# %% [markdown]
# ## 3. Gradient Descent

# %% [markdown]
# ❓ Now that you have the necessary functions for a Gradient Descent, loop through epochs until convergence.
#
# - Initialize parameters `a = 1` and  `b = 1`
# - Consider convergence to be **100 epochs**
# - Don't forget to start each new epoch with the updated parameters
# - Append the values for `loss`, `a`, and `b` at each epoch to their corresponding lists called `loss_history`, `a_history` and `b_history`

# %% [markdown]
# ![Capture%20d%E2%80%99e%CC%81cran%202022-11-03%20a%CC%80%2013.05.07.png](attachment:Capture%20d%E2%80%99e%CC%81cran%202022-11-03%20a%CC%80%2013.05.07.png)

# %%
a = 1
b = 1

loss_history = []
a_history = [1]
b_history = [1]

n = 1
while n <= 100:
    gradient_a = gradient(data_X,data_Y,a,b)[0]
    gradient_b = gradient(data_X,data_Y,a,b)[1]
    step_a = steps(gradient_a,gradient_b, learning_rate = 0.01)[0]
    step_b = steps(gradient_a,gradient_b, learning_rate = 0.01)[1]
    a = update_params(a, b, step_a, step_b)[0]
    b = update_params(a, b, step_a, step_b)[1]
    a_history.append(a)
    b_history.append(b)
    loss_history.append(loss(data_X,data_Y,a,b))
    n+=1

# %%
a = 1
b = 1

loss_history = []
a_history = [1]
b_history = [1]

n = 1
while n <= 100:
    a = update_params(a, b, steps(gradient(data_X,data_Y,a,b)[0],gradient(data_X,data_Y,a,b)[1], learning_rate = 0.01)[0], steps(gradient(data_X,data_Y,a,b)[0],gradient(data_X,data_Y,a,b)[1], learning_rate = 0.01)[1])[0]
    b = update_params(a, b, steps(gradient(data_X,data_Y,a,b)[0],gradient(data_X,data_Y,a,b)[1], learning_rate = 0.01)[0], steps(gradient(data_X,data_Y,a,b)[0],gradient(data_X,data_Y,a,b)[1], learning_rate = 0.01)[1])[1]
    a_history.append(a)
    b_history.append(b)
    loss_history.append(loss(data_X,data_Y,a,b))
    n+=1

# %% [markdown]
# ❓ What are the parameter values at the end of the 100 epochs? Save them to respective variables `a_100` and `b_100`

# %%
a_100=a_history[-1]
b_100=b_history[-1]

# %%
# 🧪 Test your code
from nbresult import ChallengeResult
result = ChallengeResult('descent',
                         a_100=a_100,
                         b_100=b_100)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.10.6, pytest-7.1.3, pluggy-1.0.0 -- /Users/florencetersier/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/florencetersier/code/FDLData/data-batch-gradient-descent/tests
# plugins: anyio-3.6.1, asyncio-0.19.0
# asyncio: mode=strict
# collecting ... collected 2 items
#
# test_descent.py::TestDescent::test_a PASSED                              [ 50%]
# test_descent.py::TestDescent::test_b PASSED                              [100%]
#
# ============================== 2 passed in 0.04s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/descent.pickle
#
# git commit -m 'Completed descent step'
#
# git push origin master

# %% [markdown]
# ## 4. Visual check

# %% [markdown]
# ❓ Wrap this iterative approach into a method `gradient_descent()` which returns your `new_a`, `new_b` and `history`, a dictionary containing these lists:
# - `loss_history`
# - `a_history`
# - `b_history`

# %%
def gradient_descent(X, Y, a_init=1, b_init=1, learning_rate=0.001, n_epochs=100):
    a = a_init
    b = b_init
    
    a_history = []
    b_history = []
    loss_history = []
    
    n = 0
    while n <= n_epochs:
        a_history.append(a)
        b_history.append(b)
        
        loss_history.append(loss(X,Y,a,b))
        
        d_a, d_b = gradient(X,Y,a,b)
        step_a, step_b = steps(d_a, d_b, learning_rate=learning_rate)
        a, b = update_params(a,b, step_a, step_b)
        
        n+=1
        
    dict_gradient = {'a': a_history, 'b': b_history, 'history': loss_history}

    return a, b, dict_gradient

# %%
a_best, b_best, dict_gradient = gradient_descent(data_X, data_Y, a_init=1, b_init=1, learning_rate=0.001, n_epochs=100)

# %%
# Plot the loss function
from matplotlib import pyplot as plt
plt.plot(dict_gradient['history'])

# %%
# Get the index of the minimum of the loss function
index = dict_gradient['history'].index(min(dict_gradient['history']))
index
# Out:
# 100

# %% [markdown]
# ❓ Plot the line of best fit through Zinc and Phosphorus using the parameters of your Gradient Descent.

# %%
# Determine the bests a and b that minimize the loss function
best_a = dict_gradient['a'][index]
best_b = dict_gradient['b'][index]

line_best_fit = best_a*data_X + best_b

# %%
fit = pd.DataFrame()
fit['X'] = data_X
fit['y'] = best_a*fit['X'] + best_b

sns.scatterplot(data=data, x='zinc', y='phosphorus')
sns.lineplot(data=fit, x='X', y='y', color='red')
# Out:
# <AxesSubplot:xlabel='zinc', ylabel='phosphorus'>

# %% [markdown]
# ## 5. Visualize your descent

# %% [markdown]
# 🎯 Our goal is to plot our loss function and the descent steps on a 2D surface using matplotlib [contourf]

# %% [markdown]
# ❓ Start by creating the data we need for the plot
# - `range_a`: a range of 100 values for `a` equally spaced between -1 and 1
# - `range_b`: a range of 100 values for `b` equally spaced between -1 and 1
# - `Z`: a 2D-array where each element `Z[j,i]` is equal to the value of the loss function at `a` = `range_a[i]` and `b` = `range_b[j]`

# %%
range_a = np.linspace(-1, 1, 100)
range_b = np.linspace(-1, 1, 100)

Z = np.zeros((len(range_a),len(range_b)))
for (i, a) in enumerate(range_a):
    for (j, b) in enumerate(range_b):
        Z[j,i] = loss(data_X,data_Y,a,b)

# %%
Z
# Out:
# array([[170.76944132, 168.99954894, 167.23995546, ...,  47.04153267,
#          46.27063305,  45.51003232],
#        [167.10067446, 165.34830149, 163.60622742, ...,  45.07214928,
#          44.31876907,  43.57568776],
#        [163.47516848, 161.74031494, 160.01576028, ...,  43.14602678,
#          42.41016599,  41.6846041 ],
#        ...,
#        [ 16.32176727,  16.25125836,  16.19104835, ...,  57.43405562,
#          58.36253947,  59.30132221],
#        [ 16.8493069 ,  16.79631741,  16.75362682, ...,  59.66097872,
#          60.60698199,  61.56328415],
#        [ 17.42010743,  17.38463735,  17.35946617, ...,  61.93116272,
#          62.89468541,  63.86850699]])

# %% [markdown]
# ❓ Now, plot in one single subplot:
# - your gradient as a 2D-surface using matplotlib [contourf](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.contourf.html) with 3 parameters
# - all historical (a,b) points as a scatterplot with red dots to visualize your gradient descent!
#
# Change your learning rate and observe its impact on the graph!

# %%
from matplotlib.pyplot import contourf

plt.contourf(range_a, range_b, Z)
plt.scatter(dict_gradient['a'], 
                dict_gradient['b'],
                color='red', s=1)
plt.colorbar()

# %% [markdown]
# ❓ [optional] What about 3D? Try to plot the same data on a [plot.ly 3D contour plot](https://plotly.com/python/3d-surface-plots/) below

# %%
import plotly.graph_objects as go

surface = go.Surface(x=range_a, y=range_b, z=Z)
scatter = go.Scatter3d(x=dict_gradient['a'], 
                       y=dict_gradient['b'], 
                       z=dict_gradient['history'], 
                       mode='markers')
fig = go.Figure(data=[surface, scatter])

fig.update_layout(title='Loss Function', autosize=False, width=500, height=500)
fig.show()
# Out:
# <div>                            <div id="0b1232e7-8f5f-43ad-9ef6-a9229464875a" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b1232e7-8f5f-43ad-9ef6-a9229464875a")) {                    Plotly.newPlot(                        "0b1232e7-8f5f-43ad-9ef6-a9229464875a",                        [{"x":[-1.0,-0.9797979797979798,-0.9595959595959596,-0.9393939393939394,-0.9191919191919192,-0.898989898989899,-0.8787878787878788,-0.8585858585858586,-0.8383838383838383,-0.8181818181818181,-0.797979797979798,-0.7777777777777778,-0.7575757575757576,-0.7373737373737373,-0.7171717171717171,-0.696969696969697,-0.6767676767676767,-0.6565656565656566,-0.6363636363636364,-0.6161616161616161,-0.5959595959595959,-0.5757575757575757,-0.5555555555555556,-0.5353535353535352,-0.5151515151515151,-0.4949494949494949,-0.4747474747474747,-0.4545454545454545,-0.43434343434343425,-0.41414141414141414,-0.3939393939393939,-0.3737373737373737,-0.3535353535353535,-0.33333333333333326,-0.31313131313131304,-0.2929292929292928,-0.2727272727272727,-0.2525252525252525,-0.23232323232323226,-0.21212121212121204,-0.19191919191919182,-0.1717171717171716,-0.1515151515151515,-0.13131313131313127,-0.11111111111111105,-0.09090909090909083,-0.07070707070707061,-0.050505050505050386,-0.030303030303030276,-0.010101010101010055,0.010101010101010166,0.030303030303030498,0.05050505050505061,0.07070707070707072,0.09090909090909105,0.11111111111111116,0.1313131313131315,0.1515151515151516,0.1717171717171717,0.19191919191919204,0.21212121212121215,0.2323232323232325,0.2525252525252526,0.27272727272727293,0.29292929292929304,0.31313131313131315,0.3333333333333335,0.3535353535353536,0.3737373737373739,0.39393939393939403,0.41414141414141437,0.4343434343434345,0.4545454545454546,0.4747474747474749,0.49494949494949503,0.5151515151515154,0.5353535353535355,0.5555555555555556,0.5757575757575759,0.595959595959596,0.6161616161616164,0.6363636363636365,0.6565656565656568,0.6767676767676769,0.696969696969697,0.7171717171717173,0.7373737373737375,0.7575757575757578,0.7777777777777779,0.7979797979797982,0.8181818181818183,0.8383838383838385,0.8585858585858588,0.8787878787878789,0.8989898989898992,0.9191919191919193,0.9393939393939394,0.9595959595959598,0.9797979797979799,1.0],"y":[-1.0,-0.9797979797979798,-0.9595959595959596,-0.9393939393939394,-0.9191919191919192,-0.898989898989899,-0.8787878787878788,-0.8585858585858586,-0.8383838383838383,-0.8181818181818181,-0.797979797979798,-0.7777777777777778,-0.7575757575757576,-0.7373737373737373,-0.7171717171717171,-0.696969696969697,-0.6767676767676767,-0.6565656565656566,-0.6363636363636364,-0.6161616161616161,-0.5959595959595959,-0.5757575757575757,-0.5555555555555556,-0.5353535353535352,-0.5151515151515151,-0.4949494949494949,-0.4747474747474747,-0.4545454545454545,-0.43434343434343425,-0.41414141414141414,-0.3939393939393939,-0.3737373737373737,-0.3535353535353535,-0.33333333333333326,-0.31313131313131304,-0.2929292929292928,-0.2727272727272727,-0.2525252525252525,-0.23232323232323226,-0.21212121212121204,-0.19191919191919182,-0.1717171717171716,-0.1515151515151515,-0.13131313131313127,-0.11111111111111105,-0.09090909090909083,-0.07070707070707061,-0.050505050505050386,-0.030303030303030276,-0.010101010101010055,0.010101010101010166,0.030303030303030498,0.05050505050505061,0.07070707070707072,0.09090909090909105,0.11111111111111116,0.1313131313131315,0.1515151515151516,0.1717171717171717,0.19191919191919204,0.21212121212121215,0.2323232323232325,0.2525252525252526,0.27272727272727293,0.29292929292929304,0.31313131313131315,0.3333333333333335,0.3535353535353536,0.3737373737373739,0.39393939393939403,0.41414141414141437,0.4343434343434345,0.4545454545454546,0.4747474747474749,0.49494949494949503,0.5151515151515154 ...

# %% [markdown]
# ❓ Plot the history of the `loss` values as a function of the number of `epochs`. Try with multiple variations of `learning_rate` from 0.001 to 0.01 and make sure to understand the difference

# %% [markdown]
# ## 6. With Sklearn...

# %% [markdown]
# ❓ Using Sklearn, train a Linear Regression model on the same data. Compare its parameters to the ones computed by your Gradient Descent.

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

X = data[['zinc']]
y = data['phosphorus']

model.fit(X, y)

print(model.coef_)
print(model.intercept_)
# Out:
# [0.76883717]
# 0.0070177202010620054

# %%
print(best_a)
print(best_b)
# Out:
# 0.768671510620374
# 0.00708932115622393

# %% [markdown]
# They should be almost identical!

# %% [markdown]
# ### 🏁 Congratulation! Please, push your exercise when you are done
